# %% [markdown]
# <a href="https://colab.research.google.com/github/shnhrtkyk/point2color/blob/main/point2color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import torch
need_pytorch3d=False
try:
    import pytorch3d
except ModuleNotFoundError:
    need_pytorch3d=True
if need_pytorch3d:
    if torch.__version__.startswith("1.9") and sys.platform.startswith("linux"):
        # We try to install PyTorch3D via a released wheel.
        version_str="".join([
            f"py3{sys.version_info.minor}_cu",
            torch.version.cuda.replace(".",""),
            f"_pyt{torch.__version__[0:5:2]}"
        ])
        # !pip install pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html
    else:
        # We try to install PyTorch3D from source.
        # !curl -LO https://github.com/NVIDIA/cub/archive/1.10.0.tar.gz
        # !tar xzf 1.10.0.tar.gz
        os.environ["CUB_HOME"] = os.getcwd() + "/cub-1.10.0"
        # !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'
# Out:
# Looking in links: https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py37_cu111_pyt190/download.html
# ...
#      |████████████████████████████████| 44.1 MB 28 kB/s
# ...
#      |████████████████████████████████| 49 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 58.3 MB/s
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20211023-py3-none-any.whl size=60947 sha256=912c6c9a05d38cbe219e2832cca31dfafd2ac7e418aafdb3ba9a9320e7303771
#   Stored in directory: /root/.cache/pip/wheels/16/98/fc/252d62cab6263c719120e06b28f3378af59b52ce7a20e81852
# Successfully built fvcore
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install laspy==1.7.0
# !pip install open3d==0.8.0.0
# !pip install torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-1.9.0+cu111.html
# Out:
# ...
# Looking in links: https://data.pyg.org/whl/torch-1.9.0+cu111.html
# ...
#      |████████████████████████████████| 10.4 MB 7.4 MB/s
# ...
#      |████████████████████████████████| 3.7 MB 52.3 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 45.8 MB/s
# ...
#      |████████████████████████████████| 870 kB 44.0 MB/s
# ...
#      |████████████████████████████████| 325 kB 13.2 MB/s
# ...
#      |████████████████████████████████| 407 kB 76.0 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.7 MB/s
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.2-py3-none-any.whl size=535570 sha256=a84d919424a838b2869e3bf732f1a6282732cb0b2afd02649b7ecb2add978285
#   Stored in directory: /root/.cache/pip/wheels/3f/08/13/2321517088bb2e95bfd0e45033bb9c923189e5b2078e0be4ef
# Successfully built torch-geometric
# ...

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 1.9.0+cu111
# 11.1

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ------------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argcomplete                   1.12.3
# argon2-cffi                   21.1.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.2
# ...

# %%
# !git clone https://github.com/shnhrtkyk/point2color.git
# Out:
# Cloning into 'point2color'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 49 (delta 8), reused 18 (delta 4), pack-reused 0
# Unpacking objects: 100% (49/49), done.

# %%
# %cd ./point2color/
# Out:
# /content/point2color

# %%
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "main.py", line 29, in <module>
#     from pointnet2_classification import SAModule, GlobalSAModule, MLP
# ModuleNotFoundError: No module named 'pointnet2_classification'

# %%
# !git clone https://github.com/pyg-team/pytorch_geometric.git
# Out:
# Cloning into 'pytorch_geometric'...
# remote: Enumerating objects: 33325, done.
# remote: Counting objects: 100% (2421/2421), done.
# remote: Compressing objects: 100% (1358/1358), done.
# remote: Total 33325 (delta 1485), reused 1749 (delta 1055), pack-reused 30904
# Receiving objects: 100% (33325/33325), 6.82 MiB | 19.78 MiB/s, done.
# Resolving deltas: 100% (24528/24528), done.

# %%
# !cp /content/point2color/main.py /content/point2color/pytorch_geometric/examples

# %%
# %cd /content/point2color/pytorch_geometric/examples
# Out:
# /content/point2color/pytorch_geometric/examples

# %%
# !python main.py
# Out:
# Namespace(b1=0.5, b2=0.999, batch_size=1, channels=3, checkpoint_interval=-1, dataset_name='mydata_point', decay_epoch=100, epoch=0, img_height=256, img_width=256, lr=0.0002, n_cpu=16, n_epochs=200, sample_interval=500)
# /content/point2color/data//pointcloud_point/
# ['/content/point2color/data//pointcloud_point/271460_3289689_4.las', '/content/point2color/data//pointcloud_point/271460_3289689_10.las', '/content/point2color/data//pointcloud_point/271460_3289689_8.las', '/content/point2color/data//pointcloud_point/271460_3289689_5.las', '/content/point2color/data//pointcloud_point/271460_3289689_3.las', '/content/point2color/data//pointcloud_point/271460_3289689_7.las', '/content/point2color/data//pointcloud_point/271460_3289689_6.las', '/content/point2color/data//pointcloud_point/271460_3289689_2.las', '/content/point2color/data//pointcloud_point/271460_3289689_9.las', '/content/point2color/data//pointcloud_point/271460_3289689_1.las']
# ...
